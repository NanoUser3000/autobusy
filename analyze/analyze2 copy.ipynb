# %%
import pandas as pd
import plotly.express as px
from lib.utils import df_from_jsonl, print_neighbours

# %%
# read from file with preprocessed data into df
data_file = 'pre_bigdata'
df = df_from_jsonl(data_file)

# %%
df.sort_values(by=['VehicleNumber', 'Time'], ascending=[True, True], inplace=True, ignore_index=True)
df.drop_duplicates(['VehicleNumber', 'Time'], inplace=True) # possible duplicate measurements
# todo: could drop vehicles with too few measurements, learn groupby
vc = df.value_counts('VehicleNumber')
# print(vc[0:20])
# print(vc)
pop_nr = vc.index[0]
pop_df = df[df['VehicleNumber'] == pop_nr]
pop_vc = pop_df.value_counts('Lines')
print(pop_vc)
line = pop_vc.index[0]

small_df = df[(df['Lines'] == line)]
print(small_df)
# lons = small_df.value_counts('Lon')
# lon_pop = lons.index[0]
# print(small_df[small_df['Lon'] == lon_pop])

# full_df = df
# df = small_df
# Out:
# Lines
# 190    1218
# Name: count, dtype: int64
#         Lines        Lon  VehicleNumber                Time        Lat Brigade
# 532253    190  21.047438           3403 2024-02-22 09:05:50  52.264145       1
# 532301    190  21.047263           3403 2024-02-22 09:37:55  52.264097       1
# 532302    190  21.047279           3403 2024-02-22 09:40:25  52.264075       1
# 532304    190  21.047279           3403 2024-02-22 09:40:40  52.264072       1
# 532305    190  21.047313           3403 2024-02-22 09:40:50  52.264053       1
# ...       ...        ...            ...                 ...        ...     ...
# 1838924   190  21.084403           8593 2024-02-22 14:27:42  52.297762     017
# 1838925   190  21.086327           8593 2024-02-22 14:27:57  52.300085     017
# 1838927   190  21.087035           8593 2024-02-22 14:28:12  52.300892     017
# 1838928   190  21.087035           8593 2024-02-22 14:28:23  52.300892     017
# 1838930   190  21.087910           8593 2024-02-22 14:29:01  52.302201     017
#
# [19410 rows x 6 columns]

# %%
# drop unupdated gps positions
def drop_gps_fails_v1(df):
    df.reset_index(drop=True, inplace=True)
    # todo dropping duplicates above becomes unnecessary
    all_count = len(df)
    dropped_count = 0
    how_far_to_look = 1
    for i in range(1, len(df)): # start from 1 to compare with previous
        prev = i - how_far_to_look
        drop_cond =  (df.at[i, 'Lon'] == df.at[prev, 'Lon']
                    and df.at[i, 'Lat'] == df.at[prev, 'Lat']
                    and df.at[i, 'VehicleNumber'] == df.at[prev, 'VehicleNumber'])
        if drop_cond:
            df.drop(i, inplace=True)
            how_far_to_look += 1
            dropped_count += 1
        else:
            how_far_to_look = 1
    print(f'Dropped {dropped_count} out of {all_count} rows')

def drop_gps_fails_v2(df):
    df.reset_index(drop=True, inplace=True)
    # todo dropping duplicates above becomes unnecessary
    all_count = len(df)
    dropped_count = 0
    how_far_to_look = 1
    for i in range(1, len(df)): # start from 1 to compare with previous
        prev = i - how_far_to_look
        drop_cond =  (df.at[i, 'Lon'] == df.at[prev, 'Lon']
                    and df.at[i, 'Lat'] == df.at[prev, 'Lat']
                    and df.at[i, 'VehicleNumber'] == df.at[prev, 'VehicleNumber'])
        if drop_cond:
            # df.drop(i, inplace=True)
            df.at[i, 'Lon'] = None
            how_far_to_look += 1
            dropped_count += 1
        else:
            how_far_to_look = 1
    print(f'Dropped {dropped_count} out of {all_count} rows')
    df.dropna(subset=['Lon'], inplace=True)

# drop_gps_fails_v2(df)
# df.reset_index(drop=True, inplace=True)

# %%
# prepare deltas dataframe
# note: df isn't changed in the process
df_prev = df.shift(1)
# todo: could guarantee vehicles are == while merging
deltas_df = df.merge(df_prev, how='outer', left_index=True, right_index=True, suffixes=('', '_prev'))
deltas_df = deltas_df[(deltas_df['VehicleNumber'] == deltas_df['VehicleNumber_prev'])
                & (deltas_df['Time'] != deltas_df['Time_prev'])]
deltas_df.drop(columns=['VehicleNumber_prev'], inplace=True)

# %%
# calculate distances and time differences
from lib.distance import earth_distance_km, warsaw_distance_km, warsaw_numbers
(km_lon, km_lat) = warsaw_numbers()

deltas_df['Time_diff'] = (deltas_df['Time'] - deltas_df['Time_prev']).dt.total_seconds()
deltas_df = deltas_df[deltas_df['Time_diff'] > 9]

# %%
deltas_df['Dist_pythagoras'] = ( ((deltas_df['Lat'] - deltas_df['Lat_prev'])*km_lat)**2 + ((deltas_df['Lon'] - deltas_df['Lon_prev'])*km_lon)**2  )**0.5
# slow pythagoras:
# deltas_df['Dist_pythagoras'] = deltas_df.apply(lambda row: warsaw_distance_km((row['Lon'], row['Lat']), (row['Lon_prev'], row['Lat_prev'])), axis=1)
deltas_df['velocity_p'] = (deltas_df['Dist_pythagoras'] / deltas_df['Time_diff']) * 3600
deltas_df = deltas_df[deltas_df['velocity_p'] < 90]

# %%
# haversine is soo slow
# deltas_df['Dist_haversine'] = deltas_df.apply(lambda row: earth_distance_km((row['Lon'], row['Lat']), (row['Lon_prev'], row['Lat_prev'])), axis=1)
# deltas_df['velocity_h'] = deltas_df['Dist_haversine'] / deltas_df['Time_diff'] * 3600

# %%
# before calculating velocities:
# TODO! filter out too big time diffs
# TODO! filter out stale positions
# deltas_df.describe()

# %%
# fig = px.line(deltas_df, x='Time', y='velocity_p', title='Velocity over time')
# fig.show()
# deltas_df['smoothed'] = deltas_df['velocity_p'].rolling(window=7).mean()
# fig = px.line(deltas_df, x='Time', y='smoothed', title='Smoothed velocity over time')
# fig.show()
# deltas_df['expon_smoothed'] = deltas_df['velocity_p'].ewm(span=7).mean()
# fig = px.line(deltas_df, x='Time', y='expon_smoothed', title='Velocity over time')
# fig.show()
# deltas_df['expon_smoothed2'] = deltas_df['velocity_p'].ewm(span=3).mean()
# fig = px.line(deltas_df, x='Time', y='expon_smoothed', title='Velocity over time')
# fig.show()

# %%
import plotly.graph_objects as go

# # scattergeo plot
# fig = go.Figure()

# fig.add_trace(go.Scattergeo(
#     lon = deltas_df['Lon'],
#     lat = deltas_df['Lat'],
#     mode = 'markers',
#     marker=dict(
#         size=8,
#         opacity=0.8,
#         reversescale=True,
#         autocolorscale=False,
#         colorscale='RdYlBu',  # nice colorscale
#         cmin=min(deltas_df['smoothed']),
#         color=deltas_df['smoothed'],
#         cmax=max(deltas_df['smoothed']),
#         colorbar_title='Velocity'
#     )
# ))

# fig.update_layout(
#     title='Velocity Map',
#     geo=dict(
#         showland=True,
#         landcolor="rgb(250, 250, 250)",
#         center=dict(lon=21.0122, lat=52.2297),
#         showcountries=True,
#         countrycolor="rgb(100, 100, 100)",
#         projection_type="equirectangular",
#         fitbounds="locations",
#     )
# )

# fig.show()

# %%
factor = 1
lon_step = 0.0025 * factor
lat_step = 0.0025 * factor

dd = deltas_df.copy()
dd['Lon_grid'] = (dd['Lon'] // lon_step) * lon_step
dd['Lat_grid'] = (dd['Lat'] // lat_step) * lat_step
averages = dd.groupby(['Lon_grid', 'Lat_grid'])['velocity_p'].mean().reset_index()
# print(averages.head(2))

fig = go.Figure()

fig.add_trace(go.Scattergeo(
    lon=averages['Lon_grid'],
    lat=averages['Lat_grid'],
    text=averages['velocity_p'].astype(str) + 'km/h',
    mode='markers',
    marker=dict(
        size=5, # could be proportional to something!
        opacity=0.8,
        reversescale=True,
        autocolorscale=False,
        colorscale='RdYlBu',
        cmin=averages['velocity_p'].min(),
        color=averages['velocity_p'],
        cmax=averages['velocity_p'].max(),
        colorbar_title='Average velocity'
    )
))

fig.update_layout(
    title='Average Velocity Map',
    geo=dict(
        showland=True,
        landcolor="rgb(250, 250, 250)",
        showcountries=True,
        countrycolor="rgb(100, 100, 100)",
        projection_type="equirectangular",
        fitbounds="locations",
    )
)

fig.show()

# %%
raise UserWarning('stop here')
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 raise UserWarning('stop here')
#
# UserWarning: stop here

# %%
df188 = deltas_df[deltas_df['Lines'] == '188'].copy()
df188['VehicleNumber'].drop_duplicates()
# df188[df188['VehicleNumber'] == 2226]
# Out:
# Series([], Name: VehicleNumber, dtype: int64)

# %%
df188[df188['VehicleNumber'] == 8842]
# Out:
#        Lines        Lon  VehicleNumber                Time        Lat Brigade  \
# 900637   188  20.979631           8842 2024-02-22 09:29:54  52.173820      07
# 900638   188  20.978821           8842 2024-02-22 09:30:29  52.177735      07
# 900639   188  20.978623           8842 2024-02-22 09:30:39  52.178550      07
# 900640   188  20.978521           8842 2024-02-22 09:30:54  52.178989      07
# 900641   188  20.978430           8842 2024-02-22 09:31:04  52.179356      07
# ...      ...        ...            ...                 ...        ...     ...
# 900924   188  21.115807           8842 2024-02-22 10:50:08  52.233854      07
# 900925   188  21.115807           8842 2024-02-22 10:50:23  52.233849      07
# 900926   188  21.115784           8842 2024-02-22 13:05:03  52.234031      07
# 900927   188  21.115799           8842 2024-02-22 13:05:13  52.233871      07
# 900928   188  21.115800           8842 2024-02-22 13:05:28  52.233829      07
#
#        Lines_prev   Lon_prev           Time_prev   Lat_prev Brigade_prev  \
# 900637        188  20.979025 2024-02-22 09:28:56  52.169480           07
# 900638        188  20.979615 2024-02-22 09:29:59  52.174328           07
# 900639        188  20.978821 2024-02-22 09:30:29  52.177735           07
# 900640        188  20.978623 2024-02-22 09:30:39  52.178550           07
# 900641        188  20.978521 2024-02-22 09:30:54  52.178989           07
# ...           ...        ...                 ...        ...          ...
# 900924        188  21.115800 2024-02-22 10:49:58  52.233858           07
# 900925        188  21.115807 2024-02-22 10:50:08  52.233854           07
# 900926        188  21.115804 2024-02-22 10:50:28  52.233849           07
# 900927        188  21.115784 2024-02-22 13:05:03  52.234031           07
# 900928        188  21.115799 2024-02-22 13:05:13  52.233871           07
#
#         Time_diff  Dist_pythagoras  velocity_p
# 900637       58.0         0.483526   30.011967
# 900638       30.0         0.382107   45.852835
# 900639       10.0         0.091437   32.917151
# 900640       15.0         0.049162   11.798971
# 900641       10.0         0.041220   14.839283
# ...           ...              ...         ...
# 900924       10.0         0.000702    0.252587
# 900925       15.0         0.000466    0.111936
# 900926     8075.0         0.020249    0.009028
# 900927       10.0         0.017823    6.416288
# 900928       15.0         0.004607    1.105590
#
# [292 rows x 14 columns]

# %%
# filter out too big velocities
threshold = 120
# TODO! filter out stale positions instead
count = len(deltas_df)
deltas_df = deltas_df[deltas_df['velocity_p'] < threshold]
count2 = len(deltas_df)
removed = count - count2
print(f"Removed {removed} out of {count} entries ({(removed)/count * 100}%).")
print(f" (Too fast -- over {threshold} km/h)")
# Out:
# Removed 246 out of 1242788 entries (0.01979420464310888%).
#  (Too fast -- over 120 km/h)

# %%
deltas_df.reset_index(inplace=True, drop=True)
# no removing from deltas_bf below

# %%
velo_max_idx = deltas_df['velocity_p'].idxmax()
print_neighbours(deltas_df, velo_max_idx)
# Out:
# Neighbours of 469327 from 469322 to 469332
# Neighbor 469322
# Lines                              500
# Lon                          21.000551
# VehicleNumber                     5449
# Time               2024-02-22 10:13:13
# Lat                          52.258583
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     20.997425
# Time_prev          2024-02-22 10:12:58
# Lat_prev                     52.258392
# Brigade_prev                         6
# Time_diff                         15.0
# Dist_pythagoras               0.214049
# velocity_p                   51.371721
# Name: 469322, dtype: object
# Neighbor 469323
# Lines                              500
# Lon                          21.002169
# VehicleNumber                     5449
# Time               2024-02-22 10:13:23
# Lat                          52.258484
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.000551
# Time_prev          2024-02-22 10:13:13
# Lat_prev                     52.258583
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.110792
# velocity_p                   39.885123
# Name: 469323, dtype: object
# Neighbor 469324
# Lines                              500
# Lon                          21.003853
# VehicleNumber                     5449
# Time               2024-02-22 10:13:33
# Lat                          52.258907
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.002169
# Time_prev          2024-02-22 10:13:23
# Lat_prev                     52.258484
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.123978
# velocity_p                   44.631983
# Name: 469324, dtype: object
# Neighbor 469325
# Lines                              500
# Lon                          21.005762
# VehicleNumber                     5449
# Time               2024-02-22 10:13:43
# Lat                          52.259483
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.003853
# Time_prev          2024-02-22 10:13:33
# Lat_prev                     52.258907
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.144938
# velocity_p                   52.177578
# Name: 469325, dtype: object
# Neighbor 469326
# Lines                              500
# Lon                          21.008533
# VehicleNumber                     5449
# Time               2024-02-22 10:14:09
# Lat                          52.260426
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.005762
# Time_prev          2024-02-22 10:13:43
# Lat_prev                     52.259483
# Brigade_prev                         6
# Time_diff                         26.0
# Dist_pythagoras               0.215881
# velocity_p                   29.891268
# Name: 469326, dtype: object
# Neighbor 469327
# Lines                              500
# Lon                          21.012907
# VehicleNumber                     5449
# Time               2024-02-22 10:14:19
# Lat                          52.261734
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.008533
# Time_prev          2024-02-22 10:14:09
# Lat_prev                     52.260426
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.331515
# velocity_p                  119.345405
# Name: 469327, dtype: object
# Neighbor 469328
# Lines                              500
# Lon                          21.020155
# VehicleNumber                     5449
# Time               2024-02-22 10:15:11
# Lat                          52.263294
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.013889
# Time_prev          2024-02-22 10:14:24
# Lat_prev                      52.26202
# Brigade_prev                         6
# Time_diff                         47.0
# Dist_pythagoras               0.449757
# velocity_p                   34.449463
# Name: 469328, dtype: object
# Neighbor 469329
# Lines                              500
# Lon                          21.020172
# VehicleNumber                     5449
# Time               2024-02-22 10:15:22
# Lat                          52.263283
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.020155
# Time_prev          2024-02-22 10:15:11
# Lat_prev                     52.263294
# Brigade_prev                         6
# Time_diff                         11.0
# Dist_pythagoras               0.001683
# velocity_p                    0.550808
# Name: 469329, dtype: object
# Neighbor 469330
# Lines                              500
# Lon                          21.020754
# VehicleNumber                     5449
# Time               2024-02-22 10:15:32
# Lat                          52.263405
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.020172
# Time_prev          2024-02-22 10:15:22
# Lat_prev                     52.263283
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.041904
# velocity_p                   15.085519
# Name: 469330, dtype: object
# Neighbor 469331
# Lines                              500
# Lon                          21.020887
# VehicleNumber                     5449
# Time               2024-02-22 10:15:42
# Lat                          52.263432
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.020754
# Time_prev          2024-02-22 10:15:32
# Lat_prev                     52.263405
# Brigade_prev                         6
# Time_diff                         10.0
# Dist_pythagoras               0.009545
# velocity_p                    3.436179
# Name: 469331, dtype: object
# Neighbor 469332
# Lines                              500
# Lon                          21.021339
# VehicleNumber                     5449
# Time               2024-02-22 10:16:03
# Lat                          52.263355
# Brigade                              6
# Lines_prev                         500
# Lon_prev                     21.020887
# Time_prev          2024-02-22 10:15:42
# Lat_prev                     52.263432
# Brigade_prev                         6
# Time_diff                         21.0
# Dist_pythagoras               0.031962
# velocity_p                    5.479184
# Name: 469332, dtype: object

# %%
print(deltas_df.columns)
print(deltas_df[['Dist_pythagoras', 'Time_diff', 'velocity_p']])
print(deltas_df[['Dist_haversine', 'Time_diff', 'velocity_h']])

deltas_df['relative_diff'] = abs(deltas_df['Dist_haversine'] - deltas_df['Dist_pythagoras']) / deltas_df['Dist_haversine']
index_max = deltas_df['relative_diff'].idxmax()
print("Max relative difference between haversine and pythagoras: ", deltas_df.loc[index_max]['relative_diff'])
print("The rest:")
print(deltas_df.loc[index_max])

index_velo_max = deltas_df['velocity_p'].idxmax()
print("Max velocity:", deltas_df.loc[index_velo_max]['velocity_p'])
print("The rest:")
print(deltas_df.loc[index_velo_max])
print("Neighbours:")
print_neighbours(deltas_df, index_velo_max)


print()
print(deltas_df['velocity_p'].describe())
print()
print(deltas_df['velocity_h'].describe())
print()
print(deltas_df['Time'].describe())
print()
print(deltas_df['Time_diff'].describe())
# Out:
# Index(['Lines', 'Lon', 'VehicleNumber', 'Time', 'Lat', 'Brigade', 'Lines_prev',
#        'Lon_prev', 'Time_prev', 'Lat_prev', 'Brigade_prev', 'Time_diff',
#        'Dist_pythagoras', 'velocity_p', 'Dist_haversine', 'velocity_h'],
#       dtype='object')
#          Dist_pythagoras  Time_diff  velocity_p
# 0               0.019910       18.0    3.981946
# 1               0.260158       27.0   34.687691
# 2               0.033994       10.0   12.237983
# 3               0.062408       14.0   16.047746
# 4               0.072192       20.0   12.994493
# ...                  ...        ...         ...
# 1339685         0.337392      120.0   10.121773
# 1339686         1.006629      120.0   30.198871
# 1339687         1.051773      120.0   31.553182
# 1339688         0.448634      120.0   13.459029
# 1339689         0.207074      120.0    6.212214
#
# [1339690 rows x 3 columns]
#          Dist_haversine  Time_diff  velocity_h
# 0              0.019921       18.0    3.984240
# 1              0.260402       27.0   34.720270
# 2              0.033990       10.0   12.236266
# 3              0.062481       14.0   16.066586
# 4              0.072266       20.0   13.007969
# ...                 ...        ...         ...
# 1339685        0.337524      120.0   10.125707
# 1339686        1.007413      120.0   30.222404
# 1339687        1.052535      120.0   31.576054
# 1339688        0.448998      120.0   13.469944
# 1339689        0.206640      120.0    6.199208
#
# [1339690 rows x 3 columns]
# Max relative difference between haversine and pythagoras:  0.006884188606234134
# The rest:
# Lines                              L47
# Lon                          21.261617
# VehicleNumber                    80105
# Time               2024-02-22 13:54:57
# Lat                          52.513229
# Brigade                              1
# Lines_prev                         L47
# Lon_prev                     21.278985
# Time_prev          2024-02-22 13:52:57
# Lat_prev                      52.51357
# Brigade_prev                         1
# Time_diff                        120.0
# Dist_pythagoras               1.184009
# velocity_p                   35.520264
# Dist_haversine                1.175914
# velocity_h                   35.277407
# relative_diff                 0.006884
# Name: 1328048, dtype: object
# Max velocity: 119.95538005583154
# The rest:
# Lines                              190
# Lon                          21.088092
# VehicleNumber                     8587
# Time               2024-02-22 12:46:52
# Lat                          52.302405
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.087087
# Time_prev          2024-02-22 12:46:47
# Lat_prev                     52.301037
# Brigade_prev                         5
# Time_diff                          5.0
# Dist_pythagoras               0.166605
# velocity_p                   119.95538
# Dist_haversine                 0.16679
# velocity_h                  120.088649
# relative_diff                  0.00111
# Name: 935246, dtype: object
# Neighbours:
# Neighbours of 935246 from 935241 to 935251
# Neighbor 935241
# Lines                              190
# Lon                          21.083243
# VehicleNumber                     8587
# Time               2024-02-22 12:45:34
# Lat                          52.296407
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.082223
# Time_prev          2024-02-22 12:45:18
# Lat_prev                     52.295118
# Brigade_prev                         5
# Time_diff                         16.0
# Dist_pythagoras               0.159006
# velocity_p                   35.776247
# Dist_haversine                0.159173
# velocity_h                   35.813887
# relative_diff                 0.001051
# Name: 935241, dtype: object
# Neighbor 935242
# Lines                              190
# Lon                          21.084925
# VehicleNumber                     8587
# Time               2024-02-22 12:45:50
# Lat                          52.298447
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.083243
# Time_prev          2024-02-22 12:45:34
# Lat_prev                     52.296407
# Brigade_prev                         5
# Time_diff                         16.0
# Dist_pythagoras               0.253781
# velocity_p                   57.100828
# Dist_haversine                0.254035
# velocity_h                    57.15777
# relative_diff                 0.000996
# Name: 935242, dtype: object
# Neighbor 935243
# Lines                              190
# Lon                          21.086438
# VehicleNumber                     8587
# Time               2024-02-22 12:46:05
# Lat                          52.300275
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.084925
# Time_prev          2024-02-22 12:45:50
# Lat_prev                     52.298447
# Brigade_prev                         5
# Time_diff                         15.0
# Dist_pythagoras               0.227634
# velocity_p                   54.632141
# Dist_haversine                0.227858
# velocity_h                   54.685866
# relative_diff                 0.000982
# Name: 935243, dtype: object
# Neighbor 935244
# Lines                              190
# Lon                          21.086997
# VehicleNumber                     8587
# Time               2024-02-22 12:46:20
# Lat                          52.300898
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.086438
# Time_prev          2024-02-22 12:46:05
# Lat_prev                     52.300275
# Brigade_prev                         5
# Time_diff                         15.0
# Dist_pythagoras               0.078958
# velocity_p                    18.94993
# Dist_haversine                0.079027
# velocity_h                   18.966515
# relative_diff                 0.000874
# Name: 935244, dtype: object
# Neighbor 935245
# Lines                              190
# Lon                          21.087087
# VehicleNumber                     8587
# Time               2024-02-22 12:46:47
# Lat                          52.301037
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.086997
# Time_prev          2024-02-22 12:46:20
# Lat_prev                     52.300898
# Brigade_prev                         5
# Time_diff                         27.0
# Dist_pythagoras               0.016541
# velocity_p                    2.205483
# Dist_haversine                0.016562
# velocity_h                    2.208204
# relative_diff                 0.001232
# Name: 935245, dtype: object
# Neighbor 935246
# Lines                              190
# Lon                          21.088092
# VehicleNumber                     8587
# Time               2024-02-22 12:46:52
# Lat                          52.302405
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.087087
# Time_prev          2024-02-22 12:46:47
# Lat_prev                     52.301037
# Brigade_prev                         5
# Time_diff                          5.0
# Dist_pythagoras               0.166605
# velocity_p                   119.95538
# Dist_haversine                 0.16679
# velocity_h                  120.088649
# relative_diff                  0.00111
# Name: 935246, dtype: object
# Neighbor 935247
# Lines                              190
# Lon                          21.088665
# VehicleNumber                     8587
# Time               2024-02-22 12:47:08
# Lat                          52.303128
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.088092
# Time_prev          2024-02-22 12:46:52
# Lat_prev                     52.302405
# Brigade_prev                         5
# Time_diff                         16.0
# Dist_pythagoras               0.089285
# velocity_p                   20.089116
# Dist_haversine                0.089376
# velocity_h                   20.109619
# relative_diff                  0.00102
# Name: 935247, dtype: object
# Neighbor 935248
# Lines                              190
# Lon                          21.088675
# VehicleNumber                     8587
# Time               2024-02-22 12:48:27
# Lat                          52.303142
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.088665
# Time_prev          2024-02-22 12:47:08
# Lat_prev                     52.303128
# Brigade_prev                         5
# Time_diff                         79.0
# Dist_pythagoras               0.001636
# velocity_p                    0.074554
# Dist_haversine                0.001638
# velocity_h                    0.074635
# relative_diff                 0.001087
# Name: 935248, dtype: object
# Neighbor 935249
# Lines                              190
# Lon                          21.088052
# VehicleNumber                     8587
# Time               2024-02-22 12:48:44
# Lat                          52.303622
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.088675
# Time_prev          2024-02-22 12:48:27
# Lat_prev                     52.303142
# Brigade_prev                         5
# Time_diff                         17.0
# Dist_pythagoras               0.068135
# velocity_p                   14.428688
# Dist_haversine                0.068153
# velocity_h                   14.432401
# relative_diff                 0.000257
# Name: 935249, dtype: object
# Neighbor 935250
# Lines                              190
# Lon                          21.085875
# VehicleNumber                     8587
# Time               2024-02-22 12:48:59
# Lat                          52.303577
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.088052
# Time_prev          2024-02-22 12:48:44
# Lat_prev                     52.303622
# Brigade_prev                         5
# Time_diff                         15.0
# Dist_pythagoras               0.148398
# velocity_p                   35.615501
# Dist_haversine                0.148085
# velocity_h                   35.540475
# relative_diff                 0.002111
# Name: 935250, dtype: object
# Neighbor 935251
# Lines                              190
# Lon                          21.085292
# VehicleNumber                     8587
# Time               2024-02-22 12:49:14
# Lat                           52.30446
# Brigade                              5
# Lines_prev                         190
# Lon_prev                     21.085875
# Time_prev          2024-02-22 12:48:59
# Lat_prev                     52.303577
# Brigade_prev                         5
# Time_diff                         15.0
# Dist_pythagoras               0.105796
# velocity_p                    25.39092
# Dist_haversine                0.105924
# velocity_h                   25.421641
# relative_diff                 0.001208
# Name: 935251, dtype: object
#
# count    1.339690e+06
# mean     1.420066e+01
# std      1.648506e+01
# min      3.810326e-05
# 25%      3.270577e-01
# 50%      7.099349e+00
# 75%      2.517856e+01
# max      1.199554e+02
# Name: velocity_p, dtype: float64
#
# count    1.339690e+06
# mean     1.420916e+01
# std      1.649459e+01
# min      3.816521e-05
# 25%      3.271591e-01
# 50%      7.105366e+00
# 75%      2.519397e+01
# max      1.201449e+02
# Name: velocity_h, dtype: float64
#
# count                          1339690
# mean     2024-02-22 11:57:27.837735680
# min                2024-02-19 02:43:16
# 25%                2024-02-22 10:39:38
# 50%                2024-02-22 12:03:38
# 75%                2024-02-22 13:20:16
# max                2024-02-22 14:29:06
# Name: Time, dtype: object
#
# count    1.339690e+06
# mean     2.410279e+01
# std      7.690533e+02
# min      1.000000e+00
# 25%      1.000000e+01
# 50%      1.200000e+01
# 75%      2.000000e+01
# max      6.036820e+05
# Name: Time_diff, dtype: float64
